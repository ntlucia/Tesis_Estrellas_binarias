# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Ellipse
import pandas as pd
from scipy.optimize import curve_fit
from scipy import integrate
import numpy as np

# %%
Data = pd.read_csv("photometry_comas.txt",delimiter=',', skiprows=0)

# %%
Data
# Out:
#                JD  Magnitude  Uncertainty  HQuncertainty  Band Observer Code  \
# 0    2.458747e+06      3.700          NaN            NaN  Vis.           REE
# 1    2.458748e+06      4.952        0.037            NaN     B           SAH
# 2    2.458748e+06      3.725        0.019            NaN     V           SAH
# 3    2.458748e+06      3.006        0.013            NaN     R           SAH
# 4    2.458748e+06      2.250        0.009            NaN     I           SAH
# ..            ...        ...          ...            ...   ...           ...
# 424  2.458839e+06      3.732        0.029            NaN    TG          LPEB
# 425  2.458840e+06      4.931        0.008            NaN     B           SAH
# 426  2.458840e+06      3.735        0.011            NaN     V           SAH
# 427  2.458840e+06      3.024        0.015            NaN     R           SAH
# 428  2.458840e+06      2.268        0.013            NaN     I           SAH
#
# ...

# %%
DatosB = Data[Data['Band'] == 'B']

# %%
JD = DatosB['JD']
Mag = DatosB['Magnitude']
error = DatosB['Uncertainty']
Banda = DatosB['Band']

# %%
fig = plt.figure(figsize=(15, 7))
plt.xlabel('Día Juliano', fontsize = 18)                  
plt.ylabel('Magnitud', fontsize = 18) 
(_, caps, _) = plt.errorbar(JD, Mag,error,0,marker ='.', ls ='', capsize=2, label='datos página')
for cap in caps:
    cap.set_markeredgewidth(1)
plt.grid()
plt.ylim((4.7,5.6))
plt.gca().invert_yaxis()
plt.legend(fontsize = 13, loc=0)
plt.show()
