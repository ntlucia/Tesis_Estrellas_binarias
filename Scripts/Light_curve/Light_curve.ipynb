# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Ellipse
import pandas as pd
from scipy.optimize import curve_fit
from scipy import integrate
import numpy as np
import datetime

# %%
#Lecture Data
Data = pd.read_csv("photometry.txt",delimiter=',', skiprows=0)
#We use band B to supplement with data taken in Vienna and Guanajuato
DatosB = Data[Data['Band'] == 'B']
DatosTB = Data[Data['Band'] == 'TB']


JD = DatosB['JD']
Mag = DatosB['Magnitude']
error = DatosB['Uncertainty']
Banda = DatosB['Band']


JD2 = DatosTB['JD']
Mag2 = DatosTB['Magnitude']
error2 = DatosTB['Uncertainty']
Banda2 = DatosTB['Band']

# %%
DatosB['JD'][425]
# Out:
# 2458839.62158

# %%
str(DatosB['JD'][1])
# Out:
# '2458747.77354'

# %%
jdtodatestd(str(DatosB['JD'][1]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-a789d4595eb6> in <module>
# ----> 1 jdtodatestd(str(DatosB['JD'][1]))
#
# <ipython-input-23-d28836399a77> in jdtodatestd(jdate)
#       1 def jdtodatestd (jdate):
#       2     fmt = '%j'
# ----> 3     datestd = datetime.datetime.strptime(jdate, fmt)
#       4     return(datestd)
#
# C:\ProgramData\Anaconda3\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     575     """Return a class cls instance based on the input string and the
#     576     format string."""
# --> 577     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     578     tzname, gmtoff = tt[-2:]
#     579     args = tt[:6] + (fraction,)
#
# C:\ProgramData\Anaconda3\lib\_strptime.py in _strptime(data_string, format)
#     360     if len(data_string) != found.end():
#     361         raise ValueError("unconverted data remains: %s" %
# --> 362                           data_string[found.end():])
#     363
#     364     iso_year = year = None
#
# ValueError: unconverted data remains: 8747.77354

# %%
#Figure: light curve
fig = plt.figure(figsize=(15, 7))
plt.xlabel('Día Juliano', fontsize = 18)                  
plt.ylabel('Magnitud', fontsize = 18) 
(_, caps, _) = plt.errorbar(JD, Mag,error,0,marker ='.', ls ='', color='darkturquoise', capsize=2, label='Filtro B')
(_, caps, _) = plt.errorbar(JD2, Mag2,error2,0,marker ='.', ls ='', color='blue',capsize=2, label='Filtro TB')

for cap in caps:
    cap.set_markeredgewidth(1)
plt.grid()
plt.ylim((4.7,5.6))
plt.gca().invert_yaxis()
plt.legend(fontsize = 13, loc=0)
plt.xticks(['17Oct', '20Oct', '23Oct','26Oct','29Oct','1Nov','4Nov'])
plt.title('Canal Azul',fontsize = 18)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1549         try:
# -> 1550             ret = self.converter.convert(x, self.units, self)
#    1551         except Exception as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\category.py in convert(value, unit, axis)
#      51             raise ValueError(
# ---> 52                 'Missing category information for StrCategoryConverter; '
#      53                 'this might be caused by unintendedly mixing categorical and '
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# <ipython-input-4-589df8a5746f> in <module>
#      12 plt.gca().invert_yaxis()
#      13 plt.legend(fontsize = 13, loc=0)
# ---> 14 plt.xticks(['17Oct', '20Oct', '23Oct','26Oct','29Oct','1Nov','4Nov'])
#      15 plt.title('Canal Azul',fontsize = 18)
#      16 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in xticks(ticks, labels, **kwargs)
#    1538         labels = ax.get_xticklabels()
#    1539     elif labels is None:
# -> 1540         locs = ax.set_xticks(ticks)
#    1541         labels = ax.get_xticklabels()
#    1542     else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in set_xticks(self, ticks, minor)
#    3347             Default is ``False``.
#    3348         """
# -> 3349         ret = self.xaxis.set_ticks(ticks, minor=minor)
#    3350         self.stale = True
#    3351         return ret
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in set_ticks(self, ticks, minor)
#    1749         """
#    1750         # XXX if the user changes units, the information will be lost here
# -> 1751         ticks = self.convert_units(ticks)
#    1752         if len(ticks) > 1:
#    1753             xleft, xright = self.get_view_interval()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1551         except Exception as e:
#    1552             raise munits.ConversionError('Failed to convert value(s) to axis '
# -> 1553                                          f'units: {x!r}') from e
#    1554         return ret
#    1555
#
# ConversionError: Failed to convert value(s) to axis units: ['17Oct', '20Oct', '23Oct', '26Oct', '29Oct', '1Nov', '4Nov']
